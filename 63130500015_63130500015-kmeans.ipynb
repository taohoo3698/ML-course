# %% [markdown]
# # K-Means Clustering Assignments
#
# **Student ID:** 63130500015
#
# **Student Name:** Chanatip Ampia

# %% [markdown]
# ---
#
# ## Assignment 1: Clustering Synthetic Data 2D Using Silhouette Coefficient
#
# ### Objective:
# Understand the concept of K-means clustering and determine the optimal number of clusters using the Silhouette Coefficient.
#
# ### Tasks:
# 1. Generate a synthetic 2D dataset with 4-5 distinct clusters using libraries like `sklearn.datasets.make_blobs`.
# 2. Visualize the dataset using a scatter plot.
# 3. Implement K-means clustering for a range of cluster numbers (e.g., 2 to 10).
# 4. For each cluster number, compute the Silhouette Coefficient.
# 5. Plot the Silhouette Coefficient values against the number of clusters to visualize the optimal number of clusters.
# 6. Visualize the clusters for the optimal number of clusters using a scatter plot.
# 7. Write a brief report discussing your findings.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Step 1: Generate synthetic dataset with 4-5 clusters
n_samples = 300
n_features = 2
n_clusters = 4
random_state = 42

X, y = make_blobs(n_samples=n_samples, n_features=n_features, centers=n_clusters, random_state=random_state)

# Step 2: Visualize the dataset
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Synthetic Dataset with Clusters')
plt.show()

# Step 3 & 4: Implement K-means and compute Silhouette Coefficient
cluster_range = range(2, 11)
silhouette_scores = []

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Step 5: Plot Silhouette Coefficient values against number of clusters
plt.plot(cluster_range, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficient')
plt.title('Silhouette Coefficient vs Number of Clusters')
plt.show()

# Step 6: Visualize clusters for the optimal number of clusters
optimal_num_clusters = cluster_range[np.argmax(silhouette_scores)]
optimal_kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=random_state)
optimal_cluster_labels = optimal_kmeans.fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=optimal_cluster_labels, cmap='viridis')
plt.scatter(optimal_kmeans.cluster_centers_[:, 0], optimal_kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'Clusters with {optimal_num_clusters} Clusters')
plt.show()
# Out:
# C:\ML\env_ml\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ML\env_ml\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ML\env_ml\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
ฺฺBrief report:
จากด้านบนเราได้ทำการวิเคราะห์ชุดข้อมูล 2 มิติโดยใช้การจัดกลุ่มแบบ K-mean และ คำนวณค่า Silhouette Coefficient เพื่อระบุจำนวนคลัสเตอร์ที่เหมาะสมที่สุดและแสดงภาพผลลัพธ์ของการจัดกลุ่มโดยมี cluster 4 กลุ่ม
ในกรณีนี้ กราฟค่า Silhouette Coefficient ช่วยให้เราตัดสินใจจำนวนกลุ่มที่เหมาะสมสำหรับชุดข้อมูลได้ จุดสูงสุดบนกราฟแสดงถึงจำนวนกลุ่มที่เหมาะสมที่สุดที่จุดข้อมูลแยกกันได้ดีและถูกกำหนดให้เข้ากับกลุ่มของตนเองได้

# %% [markdown]
# ## Assignment 2: Clustering Synthetic Data 2D Using Inertia
#
# ### Objective:
# Understand the concept of K-means clustering and determine the optimal number of clusters using inertia.
#
# ### Tasks:
# 1. Generate a synthetic 2D dataset with 4-5 distinct clusters using libraries like `sklearn.datasets.make_blobs`.
# 2. Visualize the dataset using a scatter plot.
# 3. Implement K-means clustering for a range of cluster numbers (e.g., 2 to 10).
# 4. For each cluster number, compute the inertia.
# 5. Plot the inertia values against the number of clusters to visualize the "elbow" point.
# 6. Visualize the clusters for the optimal number of clusters using a scatter plot.
# 7. Write a brief report discussing your findings.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Step 1: Generate synthetic dataset with 4-5 clusters
n_samples = 300
n_features = 2
n_clusters = 4
random_state = 42

X, y = make_blobs(n_samples=n_samples, n_features=n_features, centers=n_clusters, random_state=random_state)

# Step 2: Visualize the dataset
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Synthetic Dataset with Clusters')
plt.show()

# Step 3 & 4: Implement K-means and compute inertia
cluster_range = range(2, 11)
inertia_values = []

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
    kmeans.fit(X)
    inertia = kmeans.inertia_
    inertia_values.append(inertia)

# Step 5: Plot inertia values against number of clusters to find the elbow point
plt.plot(cluster_range, inertia_values, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia vs Number of Clusters')
plt.show()

# Step 6: Visualize clusters for the optimal number of clusters
optimal_num_clusters = 4  # You can choose the number based on the "elbow" point
optimal_kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=random_state)
optimal_cluster_labels = optimal_kmeans.fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=optimal_cluster_labels, cmap='viridis')
plt.scatter(optimal_kmeans.cluster_centers_[:, 0], optimal_kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'Clusters with {optimal_num_clusters} Clusters')
plt.show()
# Out:
# C:\ML\env_ml\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ML\env_ml\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ML\env_ml\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
ฺฺBrief report:
จากด้านบนเราได้ทำการวิเคราะห์ชุดข้อมูล 2 มิติโดยใช้การจัดกลุ่มแบบ K-mean เพื่อระบุจำนวนคลัสเตอร์ที่เหมาะสมที่สุดและแสดงภาพผลลัพธ์ของการจัดกลุ่มโดยมี cluster 4 กลุ่ม
โดยอัลกอริธึมจะกำหนดจุดให้กับคลัสเตอร์และคำนวนค่า inertia ซึ่งค่า inertia จะถูกพล็อตกราฟเทียบกับจำนวน cluster ซึ่งกราฟนี้จะช่วยกำหนดจำนวน cluster ที่เหมาะสมที่สุดได้

# %% [markdown]
# ## Assignment 3: Segmenting Patients
#
# ### Objective:
# Segment patients based on selected health metrics.
#
# ### Dataset Suggestion:
# Diabetes dataset from UCI Machine Learning Repository.
#
# ### Tasks:
# 1. Load the diabetes dataset.
# 2. Perform exploratory data analysis to understand the features and distributions.
# 3. Select two features that seem most relevant or interesting for clustering (e.g., glucose levels and age).
# 4. Visualize the selected features using a scatter plot.
# 5. Implement K-means clustering for a range of cluster numbers.
# 6. Determine the optimal number of clusters using either the Silhouette Coefficient or inertia.
# 7. Visualize the clusters using a scatter plot.
# 8. Analyze the characteristics of each cluster to understand the segmentation.
# 9. Write a report discussing the patient segments based on the selected features, potential implications, or uses of these segments in healthcare.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# Step 1: Load the diabetes dataset
diabetes = load_diabetes()
X = diabetes.data

# Step 2: Perform exploratory data analysis
# You can print information about the dataset, its features, statistics, etc.
print("Diabetes dataset features:", diabetes.feature_names)
print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1])
print("Sample data:")
print(X[:5, :])

# Step 3: Select two features for clustering
feature1_idx = 2  # Example: BMI
feature2_idx = 3  # Example: BP

selected_features = X[:, [feature1_idx, feature2_idx]]

# Step 4: Visualize selected features using a scatter plot
plt.scatter(selected_features[:, 0], selected_features[:, 1], marker='o', alpha=0.7)
plt.xlabel(diabetes.feature_names[feature1_idx])
plt.ylabel(diabetes.feature_names[feature2_idx])
plt.title('Selected Features Scatter Plot')
plt.show()

# Step 5 & 6: Implement K-means and find the optimal number of clusters
cluster_range = range(2, 11)
silhouette_scores = []

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(selected_features)
    silhouette_avg = silhouette_score(selected_features, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot Silhouette Coefficient values against number of clusters
plt.plot(cluster_range, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficient')
plt.title('Silhouette Coefficient vs Number of Clusters')
plt.show()

# Find the optimal number of clusters based on the silhouette score
optimal_num_clusters = cluster_range[np.argmax(silhouette_scores)]

# Step 7: Visualize clusters using a scatter plot
optimal_kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=42)
optimal_cluster_labels = optimal_kmeans.fit_predict(selected_features)

plt.scatter(selected_features[:, 0], selected_features[:, 1], c=optimal_cluster_labels, cmap='viridis', alpha=0.7)
plt.scatter(optimal_kmeans.cluster_centers_[:, 0], optimal_kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X')
plt.xlabel(diabetes.feature_names[feature1_idx])
plt.ylabel(diabetes.feature_names[feature2_idx])
plt.title(f'Clusters with {optimal_num_clusters} Clusters')
plt.show()

# Step 8: Analyze characteristics of each cluster
for cluster_num in range(optimal_num_clusters):
    cluster_samples = selected_features[optimal_cluster_labels == cluster_num]
    print(f"Cluster {cluster_num + 1} - Number of samples:", cluster_samples.shape[0])
    print("Mean values for selected features:", np.mean(cluster_samples, axis=0))
    print("-" * 30)
# Out:
# Diabetes dataset features: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Number of samples: 442
# Number of features: 10
# Sample data:
# [[ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#   -0.04340085 -0.00259226  0.01990749 -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 -0.02632753 -0.00844872 -0.01916334
#    0.07441156 -0.03949338 -0.06833155 -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 -0.00567042 -0.04559945 -0.03419447
#   -0.03235593 -0.00259226  0.00286131 -0.02593034]
#  [-0.08906294 -0.04464164 -0.01159501 -0.03665608  0.01219057  0.02499059
#   -0.03603757  0.03430886  0.02268774 -0.00936191]
#  [ 0.00538306 -0.04464164 -0.03638469  0.02187239  0.00393485  0.01559614
#    0.00814208 -0.00259226 -0.03198764 -0.04664087]]
# ...

# %%
Report:
จากด้านบนจะเป็นการวิเคราะห์ Diabetes dataset โดยใช้การจัดกลุ่ม K-means เพื่อระบุกลุ่มผู้ป่วยที่แตกต่างกันตามคุณลักษณะที่เกี่ยวข้อง คุณสมบัติ ระดับกลูโคส และอายุที่เลือกโดยใช้ Silhouette Coefficient 
กราฟค่า Silhouette Coefficient ช่วยให้เราตัดสินใจจำนวนกลุ่มที่เหมาะสมสำหรับชุดข้อมูลได้ จุดสูงสุดบนกราฟแสดงถึงจำนวนกลุ่มที่เหมาะสมที่สุดที่จุดข้อมูลแยกกันได้ดีและถูกกำหนดให้เข้ากับกลุ่มของตนเองได้

# %% [markdown]
# ## Assignment 4: Clustering Penguins and Evaluating with External Measure
#
# ### Objective:
# Cluster the penguin dataset and evaluate the clustering results using an external measure.
#
# ### Dataset:
# Palmer Penguins dataset, available in the `seaborn` library or on GitHub.
#
# ### Tasks:
# 1. Load the Palmer Penguins dataset.
# 2. Perform exploratory data analysis to understand the features and distributions.
# 3. Preprocess the data: handle missing values, encode categorical variables, and normalize the data.
# 4. Implement K-means clustering.
# 5. Determine the optimal number of clusters using either the Silhouette Coefficient or inertia.
# 6. Visualize the clusters using appropriate visualization techniques.
# 7. Use an external measure (e.g., Adjusted Rand Index, Normalized Mutual Information) to evaluate the clustering results against the true species labels.
# 8. Write a report discussing your findings, the effectiveness of the clustering, and the evaluation results using the external measure.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import silhouette_score, adjusted_rand_score, normalized_mutual_info_score
from sklearn.decomposition import PCA
import requests
from io import StringIO

# Load the Palmer Penguins dataset from GitHub
url = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"
response = requests.get(url)
data = StringIO(response.text)
penguins = pd.read_csv(data)

# Step 2: Exploratory Data Analysis
print(penguins.info())
print(penguins.head())

# Step 3: Preprocess the data
# Handle missing values
penguins.dropna(inplace=True)

# Encode categorical variables
encoder = LabelEncoder()
penguins['species_encoded'] = encoder.fit_transform(penguins['species'])

# Normalize the data
scaler = StandardScaler()
X = scaler.fit_transform(penguins.drop(['species', 'species_encoded'], axis=1))

# Step 4 & 5: Implement K-means and find the optimal number of clusters
cluster_range = range(2, 11)
silhouette_scores = []
inertia_values = []

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(X)
    
    silhouette_avg = silhouette_score(X, cluster_labels)
    silhouette_scores.append(silhouette_avg)
    
    inertia = kmeans.inertia_
    inertia_values.append(inertia)

# Plot Silhouette Coefficient values against number of clusters
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(cluster_range, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficient')
plt.title('Silhouette Coefficient vs Number of Clusters')

# Plot inertia values against number of clusters
plt.subplot(1, 2, 2)
plt.plot(cluster_range, inertia_values, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia vs Number of Clusters')
plt.tight_layout()
plt.show()

# Find the optimal number of clusters based on the silhouette score
optimal_num_clusters = cluster_range[np.argmax(silhouette_scores)]

# Step 6: Visualize clusters using PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

optimal_kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=42)
optimal_cluster_labels = optimal_kmeans.fit_predict(X_pca)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=optimal_cluster_labels, cmap='viridis', alpha=0.7)
plt.scatter(optimal_kmeans.cluster_centers_[:, 0], optimal_kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title(f'Clusters with {optimal_num_clusters} Clusters (PCA)')
plt.show()

# Step 7: Evaluate clustering results using external measures
true_labels = penguins['species_encoded']
ari_score = adjusted_rand_score(true_labels, optimal_cluster_labels)
nmi_score = normalized_mutual_info_score(true_labels, optimal_cluster_labels)

print(f"Adjusted Rand Index: {ari_score}")
print(f"Normalized Mutual Information: {nmi_score}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB
# None
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# ...

# %%
Report:
ในข้อนี้ให้เราใช้ตัว dataset ของ Palmer Penguins เพื่อแบ่งกลุ่มนกเพนกวินตามลักษณะทางกายภาพและประเมินประสิทธิภาพของการรวมกลุ่มโดยใช้ external measures
ใช้การจัดกลุ่มแบบ K-mean เพื่อแบ่งกลุ่มนกเพนกวินออกเป็นกลุ่มต่างๆใช้ Silhouette Coefficient วัดการแยกระหว่าง cluster 
ในการประเมินผลลัพธ์ของการจัดกลุ่มอย่างเป็นกลางเราใช้ Adjusted Rand Index (ARI) เพื่อวัดความคล้ายคลึงระหว่างป้ายชื่อสายพันธุ์ที่เป็นความจริงและผลการจัดกลุ่มค่า ARI ที่สูงแสดงถึงความตกลงที่ดีกว่าระหว่างป้ายชื่อจริงและผลการจัดกลุ่ม
